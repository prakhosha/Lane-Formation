# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.lines import Line2D
import scipy.optimize as scippy
import scipy.stats as scist
from numpy.fft import fft, ifft
import os
import shutil
from numba import njit, prange
from scipy.integrate import quad
import pandas as pd

plt.rc("xtick", labelsize=20, top=True, direction="in")
plt.rc("ytick", labelsize=20, right=True, direction="in")
plt.rc("axes", titlesize=26)
plt.rc("axes", labelsize=26)
plt.rc("legend", fontsize=26)

# %%
# Simulation parameters
N = 200
sigma = 1.0
rho = 1.0 / (sigma**2)
L = np.sqrt(N / rho)

kappa = 4.0 * sigma
r_cut = 6.0 / kappa

gamma = 1.0 # gamma=xi from previously

kBT = 1.0
V_0 = 2.5
U_0 = V_0 / kBT

tau = gamma * sigma**2 / V_0 # Time unit for everything
dt = 1e-4 * tau
t_equil = 20.0 * tau
t_prod = 50.0 * tau
# t_sim = t_equil + t_prod

n_steps_equil = int(t_equil / dt)
n_steps_prod = int(t_prod / dt)

# %%
# Minimum image convention
@njit(fastmath=True)
def min_image(dx, L):
    return dx - L * np.round(dx / L)

# Might want to smoothe the cutoff later
@njit(fastmath=True)
def V_Yuk(r):
    if 0 < r < r_cut:
        return V_0*sigma/r * np.exp( -kappa*(r-sigma) )
    elif r >= r_cut:
        return 0.0
    else:
        raise ValueError

# Quotient rule derivative; double-check at some point
@njit(fastmath=True)
def F_Yuk(r):
    if r < 1e-8 or r > r_cut:
        return 0.0
    return V_0 * sigma * np.exp(-kappa * (r - sigma)) * (kappa * r + 1) / r**2

# Intialize particles on a 2D grid, deleting some randomly if N isn't a square number
def init_grid(L, N):
    # Find smallest integer grid size n such that n^2 >= N
    n = int(np.ceil(np.sqrt(N)))

    # Build n×n grid
    coords = np.linspace(0.5*sigma, L - 0.5*sigma, n)
    X, Y= np.meshgrid(coords, coords, indexing='ij')
    pts = np.column_stack([X.ravel(), Y.ravel()])

    # Randomly choose exactly N points, implicitly deleting the rest by replace=False
    idx = np.random.choice(len(pts), N, replace=False)
    return pts[idx]

# Compute the forces using the Yukawa interaction AND the external driving
@njit(fastmath=True)
def compute_forces(pos):
    forces = np.zeros((N, 2))

    for i in range(N):
        xi, yi = pos[i]

        for j in range(i + 1, N):
            dx = min_image(xi - pos[j, 0], L)
            dy = min_image(yi - pos[j, 1], L)
            r = np.sqrt(dx*dx + dy*dy)

            F_mag = F_Yuk(r) # Magnitude of the force

            if r < r_cut:

                fx = F_mag * dx / r
                fy = F_mag * dy / r

                forces[i, 0] += fx
                forces[i, 1] += fy

                forces[j, 0] -= fx
                forces[j, 1] -= fy
            
    return forces

# Brownian Dynamics integration step
@njit(fastmath=True)
def bd_step_equil(pos):
    F_matrix = compute_forces(pos)
    noise = np.sqrt(2 * kBT * dt / gamma) * np.random.normal(0.0, 1.0, (N, 2)) # Add thermal noise
    pos = pos + dt * F_matrix / gamma + noise # Update positions with forces and noise

    for i in range(N):
        pos[i,0] -= L * np.floor(pos[i,0] / L) # Apply periodic boundary conditions
        pos[i,1] -= L * np.floor(pos[i,1] / L)

    return pos

# Brownian Dynamics integration step with species
@njit(fastmath=True)
def bd_step_drive(pos, species, F_D):
    F_matrix = compute_forces(pos)
    F_matrix[:,0] += species * F_D # external driving force

    noise = np.sqrt(2 * kBT * dt / gamma) * np.random.normal(0.0, 1.0, (N, 2)) # Add thermal noise
    pos = pos + dt * F_matrix / gamma + noise # Update positions with forces and noise

    for i in range(N):
        pos[i,0] -= L * np.floor(pos[i,0] / L) # Apply periodic boundary conditions
        pos[i,1] -= L * np.floor(pos[i,1] / L)

    return pos

# g(r) computation
@njit
def compute_gr(pos, r_max, dr):
    n_bins = int(r_max / dr)
    hist = np.zeros(n_bins)

    for i in range(N):
        xi, yi = pos[i]
        for j in range(i+1, N):
            dx = min_image(xi - pos[j,0], L)
            dy = min_image(yi - pos[j,1], L)
            r = np.sqrt(dx*dx + dy*dy)

            if r < r_max:
                bin_idx = int(r / dr)
                hist[bin_idx] += 2.0

    return hist

def write_ovito(filename, pos, species, L, step):
    N = pos.shape[0]
    with open(filename, "a") as f:
        f.write("ITEM: TIMESTEP\n")
        f.write(f"{step}\n")
        f.write("ITEM: NUMBER OF ATOMS\n")
        f.write(f"{N}\n")
        f.write("ITEM: BOX BOUNDS pp pp pp\n")
        f.write(f"0 {L}\n")
        f.write(f"0 {L}\n")
        f.write(f"0 1\n")
        f.write("ITEM: ATOMS id type x y z\n")

        for i in range(N):
            atom_id = i + 1
            atom_type = 1 if species[i] == 1 else 2
            x, y = pos[i]
            f.write(f"{atom_id} {atom_type} {x} {y} 0.0\n")

def create_last_snapshot(pos, species, F_D):
    df = pd.DataFrame(dict(L=pos[:,0], R=pos[:,1], label=species))
    groups = df.groupby('label')

    fig, ax = plt.subplots(figsize=(6, 6))
    for particle, group in groups:
        ax.scatter(group.L, group.R, label=particle)
        ax.legend(bbox_to_anchor=(1, 1))
        ax.set_aspect('equal')
        fig.tight_layout()
        #fig.savefig('last_snapshotF_D_%s.png' % F_D)


def save_dict(pos, species, ):
    saved_var = {'pos' : pos, 'species': species}
    np.save('saved_var.npy',  saved_var) 


# Phi calculation, onset of lane formation
@njit(fastmath=True)
def compute_phi(N, pos, species, L, r_l):
    phi = np.zeros(N)

    for i in range(N):
        yi = pos[i,1]
        fi = species[i]

        isolated = True

        for j in range(N):

            if species[j] == fi:
                continue
            
            dy = yi - pos[j,1]
            dy -= L * np.round(dy/L)

            if abs(dy) < r_l:
                isolated = False
                break

        phi[i] = 1.0 if isolated else 0.0

    return phi.mean()

# %%
F_D = 150 * kBT / sigma

# %%
# Main simulation
pos = init_grid(L, N)
pos0 = pos.copy()

# Species labels f_i = ±1
species = np.ones(N)
species[:N // 2] = -1
np.random.shuffle(species)

r_l = 0.5 / np.sqrt(rho)
Phi_t = []

print("Running Equilibration...")
# Equilibration
for step in range(n_steps_equil):
    #pos_old = pos.copy()
    pos = bd_step_equil(pos)
    
    #dx = pos[:,0] - pos_old[:,0]
    #dx = min_image(dx, L)
    #vx = dx/dt
     
    #vx_A.append(np.mean(vx[species == 1]))
    #vx_B.append(np.mean(vx[species == -1]))
     
    if step % (n_steps_equil // 10) == 0:
        print(f"Progress: {100 * step / n_steps_equil:.0f}%")
                      
        #vA = np.mean(vx_A)
        #vB = np.mean(vx_B)
        
        # Ovito
        dumpfile = "task4.dump"
        open(dumpfile, "w").close()
print("Equilibration finished.")        

for step in range(n_steps_prod):
    pos_old = pos.copy()
    pos = bd_step_drive(pos, species, F_D)
    
    #dx = pos[:,0] - pos_old[:,0]
    #dx = min_image(dx, L)
    #vx = dx/dt
     
    #vx_A.append(np.mean(vx[species == 1]))
    #vx_B.append(np.mean(vx[species == -1]))
     
    if step % (n_steps_prod // 10) == 0:
        print(f"Progress: {100 * step / n_steps_prod:.0f}%")

    if step % 100 == 0:
        Phi = compute_phi(N, pos, species, L, r_l)
        Phi_t.append(Phi)
        
    if step % 10 == 0:
        write_ovito(dumpfile, pos, species, L, step)
        
print("Simulation finished.")
                
#vA = np.mean(vx_A)
#vB = np.mean(vx_B)
        
#print("Measured ⟨v_x⟩ (A):", vA)
#text_file.write("Measured ⟨v_x⟩ (A): %s\n" % vA)
#print("Measured ⟨v_x⟩ (B):", vB)
#text_file.write("Measured ⟨v_x⟩ (B): %s\n" % vB)
#print("Theory F_D/γ:", F_D / gamma)
#theo_v = F_D/gamma
#text_file.write("Theory F_D/γ: %s\n\n\n" % theo_v)
#print("")
#print("")
#print("")
#print("")
        
create_last_snapshot(pos, species, F_D)

#text_file.close()
# Out:
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Equilibration finished.
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.

# %% [markdown]
# # Mean Velocity vs F_D particle A

# %%
# Simulation parameters
N = 200
sigma = 1.0
rho = 1.0 / (sigma**2)
L = np.sqrt(N / rho)

kappa = 4.0 * sigma
r_cut = 6.0 / kappa

gamma = 1.0 # gamma=xi from previously

kBT = 1.0
V_0 = 2.5
U_0 = V_0 / kBT

tau = gamma * sigma**2 / V_0 # Time unit for everything
dt = 1e-4 * tau
t_equil = 20.0 * tau
t_prod = 50.0 * tau
# t_sim = t_equil + t_prod

n_steps_equil = int(t_equil / dt)
n_steps_prod = int(t_prod / dt)

# %%
F_Ds = np.linspace(0,150,20)
F_Ds = F_Ds * kBT / sigma

# %%
# Main simulation
text_file = open("task4_result.txt", "w", encoding="utf-8")
Phis = []

for F_D in F_Ds:
        print("F_D: %s" % F_D)
        text_file.write("Summary F_D: %s\n" % F_D)
        pos = init_grid(L, N)
        pos0 = pos.copy()

        # Species labels f_i = ±1
        species = np.ones(N)
        species[:N // 2] = -1
        np.random.shuffle(species)

        r_l = 0.5 / np.sqrt(rho)
        Phi_t = []

        vx_A = []
        vx_B = []

        print("Running Equilibration...")
        # Equilibration
        for step in range(n_steps_equil):
               pos_old = pos.copy()
               pos = bd_step_equil(pos)
               
               dx = pos[:,0] - pos_old[:,0]
               dx = min_image(dx, L)
               vx = dx/dt
               
               vx_A.append(np.mean(vx[species == 1]))
               vx_B.append(np.mean(vx[species == -1]))
               
               if step % (n_steps_equil // 10) == 0:
                      print(f"Progress: {100 * step / n_steps_equil:.0f}%")
                      
        vA = np.mean(vx_A)
        vB = np.mean(vx_B)
        
        print("Measured ⟨v_x⟩ (A) at equilibration:", vA)
        text_file.write("Measured ⟨v_x⟩ (A) at equilibration: %s\n" % vA)
        print("Measured ⟨v_x⟩ (B) at equilibration:", vB)
        text_file.write("Measured ⟨v_x⟩ (B) at equilibration: %s\n" % vB)
        print("Running Brownian Dynamics simulation...")
        
        # Ovito
        dumpfile = "task3_F_D_%s.dump" % F_D
        open(dumpfile, "w").close()
        
        vx_A = []
        vx_B = []
        
        for step in range(n_steps_prod):
                pos_old = pos.copy()
                pos = bd_step_drive(pos, species, F_D)
                
                dx = pos[:,0] - pos_old[:,0]
                dx = min_image(dx, L)
                vx = dx/dt
                
                vx_A.append(np.mean(vx[species == 1]))
                vx_B.append(np.mean(vx[species == -1]))
                
                if step % (n_steps_prod // 10) == 0:
                        print(f"Progress: {100 * step / n_steps_prod:.0f}%")

                if step % 100 == 0:
                        Phi = compute_phi(N, pos, species, L, r_l)
                        Phi_t.append(Phi)
                        
                if step % 10 == 0:
                        write_ovito(dumpfile, pos, species, L, step)
                        
        print("Simulation finished.")
                
        vA = np.mean(vx_A)
        vB = np.mean(vx_B)
        
        Phis.append(Phi)
        print("Phi:", Phi)
        text_file.write("Phi: %s\n" % Phi)
        print("Measured ⟨v_x⟩ (A):", vA)
        text_file.write("Measured ⟨v_x⟩ (A): %s\n" % vA)
        print("Measured ⟨v_x⟩ (B):", vB)
        text_file.write("Measured ⟨v_x⟩ (B): %s\n" % vB)
        print("Theory F_D/γ:", F_D / gamma)
        theo_v = F_D/gamma
        text_file.write("Theory F_D/γ: %s\n\n\n" % theo_v)
        print("")
        print("")
        print("")
        print("")
        
        create_last_snapshot(pos, species, F_D)

text_file.close()
# Out:
# F_D: 0.0
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.07656540863072281
# Measured ⟨v_x⟩ (B) at equilibration: 0.09072655145414057
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.04456453799483415
# Measured ⟨v_x⟩ (B): -0.005418894048540377
# Theory F_D/γ: 0.0
#
#
#
#
# F_D: 7.894736842105263
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.0185258506996136
# Measured ⟨v_x⟩ (B) at equilibration: 0.020670823932128046
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 2.72154646109208
# Measured ⟨v_x⟩ (B): -2.739780155101695
# Theory F_D/γ: 7.894736842105263
#
#
#
#
# F_D: 15.789473684210526
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.0025362763948579294
# Measured ⟨v_x⟩ (B) at equilibration: 0.00043584090721216666
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 7.375363357493331
# Measured ⟨v_x⟩ (B): -7.378829371520349
# Theory F_D/γ: 15.789473684210526
#
#
#
#
# F_D: 23.684210526315788
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.029066460182165733
# Measured ⟨v_x⟩ (B) at equilibration: -0.05526319031640711
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 13.163419016444072
# Measured ⟨v_x⟩ (B): -13.130045155217577
# Theory F_D/γ: 23.684210526315788
#
#
#
#
# F_D: 31.57894736842105
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.004619502910184688
# Measured ⟨v_x⟩ (B) at equilibration: -0.013505628500148142
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 19.5979250750208
# Measured ⟨v_x⟩ (B): -19.575681303488082
# Theory F_D/γ: 31.57894736842105
#
#
#
#
# F_D: 39.473684210526315
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.006672438879018806
# Measured ⟨v_x⟩ (B) at equilibration: -0.04220178959647385
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 27.06823687098525
# Measured ⟨v_x⟩ (B): -27.069879428747825
# Theory F_D/γ: 39.473684210526315
#
#
#
#
# F_D: 47.368421052631575
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.04154046391147813
# Measured ⟨v_x⟩ (B) at equilibration: -0.06487833558032781
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.08
# Measured ⟨v_x⟩ (A): 34.19894521966797
# Measured ⟨v_x⟩ (B): -34.20219833206208
# Theory F_D/γ: 47.368421052631575
#
#
#
#
# F_D: 55.26315789473684
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.023100837455106063
# Measured ⟨v_x⟩ (B) at equilibration: -0.03159523265867372
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.1
# Measured ⟨v_x⟩ (A): 42.87206006775995
# Measured ⟨v_x⟩ (B): -42.90403717572723
# Theory F_D/γ: 55.26315789473684
#
#
#
#
# F_D: 63.1578947368421
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.033780687962219155
# Measured ⟨v_x⟩ (B) at equilibration: 0.0836710535880201
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 54.33058291472223
# Measured ⟨v_x⟩ (B): -54.343238257826506
# Theory F_D/γ: 63.1578947368421
#
#
#
#
# F_D: 71.05263157894737
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.04453847712538483
# Measured ⟨v_x⟩ (B) at equilibration: -0.006153127617340202
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.815
# Measured ⟨v_x⟩ (A): 63.43845249860253
# Measured ⟨v_x⟩ (B): -63.45617848103119
# Theory F_D/γ: 71.05263157894737
#
#
#
#
# F_D: 78.94736842105263
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.004580198346258032
# Measured ⟨v_x⟩ (B) at equilibration: 0.011045396864510917
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.86
# Measured ⟨v_x⟩ (A): 76.89706252238538
# Measured ⟨v_x⟩ (B): -76.87103184179475
# Theory F_D/γ: 78.94736842105263
#
#
#
#
# F_D: 86.84210526315789
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.015166956738883484
# Measured ⟨v_x⟩ (B) at equilibration: -0.0035391487972612845
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.985
# Measured ⟨v_x⟩ (A): 84.09127391016031
# Measured ⟨v_x⟩ (B): -84.1190203241391
# Theory F_D/γ: 86.84210526315789
#
#
#
#
# F_D: 94.73684210526315
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.025775305022209753
# Measured ⟨v_x⟩ (B) at equilibration: 0.0469572967149645
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 1.0
# Measured ⟨v_x⟩ (A): 93.42416576934669
# Measured ⟨v_x⟩ (B): -93.40652029907773
# Theory F_D/γ: 94.73684210526315
#
#
#
#
# F_D: 102.63157894736841
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.009944023379621745
# Measured ⟨v_x⟩ (B) at equilibration: -0.017576013330742955
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.925
# Measured ⟨v_x⟩ (A): 101.21938048907546
# Measured ⟨v_x⟩ (B): -101.27078409285085
# Theory F_D/γ: 102.63157894736841
#
#
#
#
# F_D: 110.52631578947368
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.041375265249028695
# Measured ⟨v_x⟩ (B) at equilibration: 0.03120525471595228
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.98
# Measured ⟨v_x⟩ (A): 109.34975626723563
# Measured ⟨v_x⟩ (B): -109.42397388928987
# Theory F_D/γ: 110.52631578947368
#
#
#
#
# F_D: 118.42105263157895
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.06866441070939362
# Measured ⟨v_x⟩ (B) at equilibration: 0.07242266254139855
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.94
# Measured ⟨v_x⟩ (A): 117.50170177730354
# Measured ⟨v_x⟩ (B): -117.50040156779129
# Theory F_D/γ: 118.42105263157895
#
#
#
#
# F_D: 126.3157894736842
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.04936158414435872
# Measured ⟨v_x⟩ (B) at equilibration: -0.047738918270771286
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.75
# Measured ⟨v_x⟩ (A): 125.39027130706974
# Measured ⟨v_x⟩ (B): -125.44346967624689
# Theory F_D/γ: 126.3157894736842
#
#
#
#
# F_D: 134.21052631578948
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.004387694438219543
# Measured ⟨v_x⟩ (B) at equilibration: 0.010644513741550123
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.95
# Measured ⟨v_x⟩ (A): 133.20956118395512
# Measured ⟨v_x⟩ (B): -133.24311802811505
# Theory F_D/γ: 134.21052631578948
#
#
#
#
# F_D: 142.10526315789474
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.02861552111003503
# Measured ⟨v_x⟩ (B) at equilibration: 0.05724755682894224
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.935
# Measured ⟨v_x⟩ (A): 140.97907753085937
# Measured ⟨v_x⟩ (B): -140.9047659553835
# Theory F_D/γ: 142.10526315789474
#
#
#
#
# F_D: 150.0
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.06094998628705426
# Measured ⟨v_x⟩ (B) at equilibration: -0.012949401094750276
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.925
# Measured ⟨v_x⟩ (A): 148.97390334848376
# Measured ⟨v_x⟩ (B): -148.988132590105
# Theory F_D/γ: 150.0

# %%
plt.plot(F_Ds, Phis)
plt.xlabel(r"$F_D$")
plt.ylabel(r"$\Phi$")
plt.legend(bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.grid()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Varrying densities

# %%
# Simulation parameters
N = 200
sigma = 1.0
rhos = np.linspace(0.01, 1, 5) / (sigma**2)
Ls = np.sqrt(N / rhos)

kappa = 4.0 * sigma
r_cut = 6.0 / kappa

gamma = 1.0 # gamma=xi from previously

kBT = 1.0
V_0 = 2.5
U_0 = V_0 / kBT

tau = gamma * sigma**2 / V_0 # Time unit for everything
dt = 1e-4 * tau
t_equil = 20.0 * tau
t_prod = 50.0 * tau
# t_sim = t_equil + t_prod

n_steps_equil = int(t_equil / dt)
n_steps_prod = int(t_prod / dt)

# %%
# Minimum image convention
@njit(fastmath=True)
def min_image(dx, L):
    return dx - L * np.round(dx / L)

# Might want to smoothe the cutoff later
@njit(fastmath=True)
def V_Yuk(r):
    if 0 < r < r_cut:
        return V_0*sigma/r * np.exp( -kappa*(r-sigma) )
    elif r >= r_cut:
        return 0.0
    else:
        raise ValueError

# Quotient rule derivative; double-check at some point
@njit(fastmath=True)
def F_Yuk(r):
    if r < 1e-8 or r > r_cut:
        return 0.0
    return V_0 * sigma * np.exp(-kappa * (r - sigma)) * (kappa * r + 1) / r**2

# Intialize particles on a 2D grid, deleting some randomly if N isn't a square number
def init_grid(L, N):
    # Find smallest integer grid size n such that n^2 >= N
    n = int(np.ceil(np.sqrt(N)))

    # Build n×n grid
    coords = np.linspace(0.5*sigma, L - 0.5*sigma, n)
    X, Y= np.meshgrid(coords, coords, indexing='ij')
    pts = np.column_stack([X.ravel(), Y.ravel()])

    # Randomly choose exactly N points, implicitly deleting the rest by replace=False
    idx = np.random.choice(len(pts), N, replace=False)
    return pts[idx]

# Compute the forces using the Yukawa interaction AND the external driving
@njit(fastmath=True)
def compute_forces(pos):
    forces = np.zeros((N, 2))

    for i in range(N):
        xi, yi = pos[i]

        for j in range(i + 1, N): # <-- Only compute j > i to utilize the symmetry
            dx = min_image(xi - pos[j, 0], L)
            dy = min_image(yi - pos[j, 1], L)
            r = np.sqrt(dx*dx + dy*dy)

            F_mag = F_Yuk(r) # Magnitude of the force

            if r < r_cut:

                fx = F_mag * dx / r
                fy = F_mag * dy / r

                # Apply Newton's third law / symmetry of the force matrix:
                forces[i, 0] += fx
                forces[i, 1] += fy

                forces[j, 0] -= fx
                forces[j, 1] -= fy
            
    return forces

# Brownian Dynamics integration step
@njit(fastmath=True)
def bd_step_equil(pos):
    F_matrix = compute_forces(pos)
    noise = np.sqrt(2 * kBT * dt / gamma) * np.random.normal(0.0, 1.0, (N, 2)) # Add thermal noise
    pos = pos + dt * F_matrix / gamma + noise # Update positions with forces and noise

    for i in range(N):
        pos[i,0] -= L * np.floor(pos[i,0] / L) # Apply periodic boundary conditions
        pos[i,1] -= L * np.floor(pos[i,1] / L)

    return pos

# Brownian Dynamics integration step with species
@njit(fastmath=True)
def bd_step_drive(pos):
    F_matrix = compute_forces(pos)
    F_matrix[:,0] += species * F_D # external driving force

    noise = np.sqrt(2 * kBT * dt / gamma) * np.random.normal(0.0, 1.0, (N, 2)) # Add thermal noise
    pos = pos + dt * F_matrix / gamma + noise # Update positions with forces and noise

    for i in range(N):
        pos[i,0] -= L * np.floor(pos[i,0] / L) # Apply periodic boundary conditions
        pos[i,1] -= L * np.floor(pos[i,1] / L)

    return pos

# g(r) computation
@njit
def compute_gr(pos, r_max, dr):
    n_bins = int(r_max / dr)
    hist = np.zeros(n_bins)

    for i in range(N):
        xi, yi = pos[i]
        for j in range(i+1, N):
            dx = min_image(xi - pos[j,0], L)
            dy = min_image(yi - pos[j,1], L)
            r = np.sqrt(dx*dx + dy*dy)

            if r < r_max:
                bin_idx = int(r / dr)
                hist[bin_idx] += 2.0

    return hist

def write_ovito(filename, pos, species, L, step):
    N = pos.shape[0]
    with open(filename, "a") as f:
        f.write("ITEM: TIMESTEP\n")
        f.write(f"{step}\n")
        f.write("ITEM: NUMBER OF ATOMS\n")
        f.write(f"{N}\n")
        f.write("ITEM: BOX BOUNDS pp pp pp\n")
        f.write(f"0 {L}\n")
        f.write(f"0 {L}\n")
        f.write(f"0 1\n")
        f.write("ITEM: ATOMS id type x y z\n")

        for i in range(N):
            atom_id = i + 1
            atom_type = 1 if species[i] == 1 else 2
            x, y = pos[i]
            f.write(f"{atom_id} {atom_type} {x} {y} 0.0\n")

def create_last_snapshot(pos, species, F_D):
    df = pd.DataFrame(dict(L=pos[:,0], R=pos[:,1], label=species))
    groups = df.groupby('label')

    fig, ax = plt.subplots(figsize=(6, 6))
    for particle, group in groups:
        ax.scatter(group.L, group.R, label=particle)
        ax.legend(bbox_to_anchor=(1, 1))
        ax.set_aspect('equal')
        fig.tight_layout()
        #fig.savefig('last_snapshotF_D_%s.png' % F_D)


def save_dict(pos, species, ):
    saved_var = {'pos' : pos, 'species': species}
    np.save('saved_var.npy',  saved_var) 


# Phi calculation, onset of lane formation
@njit(fastmath=True)
def compute_phi(N, pos, species, L, r_l):
    phi = np.zeros(N)

    for i in range(N):
        yi = pos[i,1]
        fi = species[i]

        isolated = True

        for j in range(N):

            if species[j] == fi:
                continue
            
            dy = yi - pos[j,1]
            dy -= L * np.round(dy/L)

            if abs(dy) < r_l:
                isolated = False
                break

        phi[i] = 1.0 if isolated else 0.0
    return phi.mean()

# %%
F_Ds = np.linspace(0,150,20)
F_Ds = F_Ds * kBT / sigma

# %%
# Main simulation
text_file = open("task4c_result.txt", "w", encoding="utf-8")
Phiss = []

for index in range(len(rhos)):
    Phis = []
    for F_D in F_Ds:

        L = Ls[index].item()
        rho = rhos[index].item()
        
        print("F_D: %s" % F_D)
        text_file.write("Summary F_D: %s\n" % F_D)
        pos = init_grid(L, N)
        pos0 = pos.copy()

        # Species labels f_i = ±1
        species = np.ones(N)
        species[:N // 2] = -1
        np.random.shuffle(species)

        r_l = 0.5 / np.sqrt(rho)

        vx_A = []
        vx_B = []

        print("Running Equilibration...")
        # Equilibration
        for step in range(n_steps_equil):
            pos_old = pos.copy()
            pos = bd_step_equil(pos)
                
            dx = pos[:,0] - pos_old[:,0]
            dx = min_image(dx, L)
            vx = dx/dt
                
            vx_A.append(np.mean(vx[species == 1]))
            vx_B.append(np.mean(vx[species == -1]))
                
            if step % (n_steps_equil // 10) == 0:
                print(f"Progress: {100 * step / n_steps_equil:.0f}%")
                      
        vA = np.mean(vx_A)
        vB = np.mean(vx_B)
        
        print("Measured ⟨v_x⟩ (A) at equilibration:", vA)
        text_file.write("Measured ⟨v_x⟩ (A) at equilibration: %s\n" % vA)
        print("Measured ⟨v_x⟩ (B) at equilibration:", vB)
        text_file.write("Measured ⟨v_x⟩ (B) at equilibration: %s\n" % vB)
        print("Running Brownian Dynamics simulation...")
        
    # Ovito
    #dumpfile = "task3_F_D_%s.dump" % F_D
    #open(dumpfile, "w").close()
        
        vx_A = []
        vx_B = []
                
        for step in range(n_steps_prod):
            pos_old = pos.copy()
            pos = bd_step_drive(pos)
                      
            dx = pos[:,0] - pos_old[:,0]
            dx = min_image(dx, L)
            vx = dx/dt
                      
            vx_A.append(np.mean(vx[species == 1]))
            vx_B.append(np.mean(vx[species == -1]))
                      
            if step % (n_steps_prod // 10) == 0:
                print(f"Progress: {100 * step / n_steps_prod:.0f}%")
                           
            #if step % 100 == 0:
            #    Phi = compute_phi(N, pos, species, L, r_l)
            #        Phi_t.append(Phi)
                        
            #if step % 10 == 0:
            #        write_ovito(dumpfile, pos, species, L, step)
                        
        print("Simulation finished.")
                
        vA = np.mean(vx_A)
        vB = np.mean(vx_B)
        
        Phi = compute_phi(N, pos, species, L, r_l)
        Phis.append(Phi)
        print("Phi:", Phi)
        text_file.write("Phi: %s\n" % Phi)
        print("Measured ⟨v_x⟩ (A):", vA)
        text_file.write("Measured ⟨v_x⟩ (A): %s\n" % vA)
        print("Measured ⟨v_x⟩ (B):", vB)
        text_file.write("Measured ⟨v_x⟩ (B): %s\n" % vB)
        print("Theory F_D/γ:", F_D / gamma)
        theo_v = F_D/gamma
        text_file.write("Theory F_D/γ: %s\n\n\n" % theo_v)
        print("")
        print("")
        print("")
        print("")
        
        create_last_snapshot(pos, species, F_D)
    Phiss.append(Phis)

text_file.close()
# Out:
# F_D: 0.0
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.09828270400465615
# Measured ⟨v_x⟩ (B) at equilibration: -0.06589034811862886
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.007230212678227358
# Measured ⟨v_x⟩ (B): -0.02740898797740876
# Theory F_D/γ: 0.0
#
#
#
#
# F_D: 7.894736842105263
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.03885729066298919
# Measured ⟨v_x⟩ (B) at equilibration: -0.004616933041463663
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.0015769546325106365
# Measured ⟨v_x⟩ (B): -0.01384955483537885
# Theory F_D/γ: 7.894736842105263
#
#
#
#
# F_D: 15.789473684210526
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.020608072391773705
# Measured ⟨v_x⟩ (B) at equilibration: 0.04005793048733254
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.02064572784844138
# Measured ⟨v_x⟩ (B): -0.012546313475483196
# Theory F_D/γ: 15.789473684210526
#
#
#
#
# F_D: 23.684210526315788
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.05556984067062116
# Measured ⟨v_x⟩ (B) at equilibration: 0.003525613654568509
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.0042415504338723774
# Measured ⟨v_x⟩ (B): -0.035107268249261955
# Theory F_D/γ: 23.684210526315788
#
#
#
#
# F_D: 31.57894736842105
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.04767888965208413
# Measured ⟨v_x⟩ (B) at equilibration: -0.011182725708823423
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.031053608048924167
# Measured ⟨v_x⟩ (B): -0.055909452631104105
# Theory F_D/γ: 31.57894736842105
#
#
#
#
# F_D: 39.473684210526315
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.05132168483549375
# Measured ⟨v_x⟩ (B) at equilibration: -0.031132006977898145
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.02243802063703639
# Measured ⟨v_x⟩ (B): 0.0017834155677785978
# Theory F_D/γ: 39.473684210526315
#
#
#
#
# F_D: 47.368421052631575
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.10277226444732487
# Measured ⟨v_x⟩ (B) at equilibration: -0.02595958041104303
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.04423045772565515
# Measured ⟨v_x⟩ (B): -0.018815366616635458
# Theory F_D/γ: 47.368421052631575
#
#
#
#
# F_D: 55.26315789473684
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.09393653605920678
# Measured ⟨v_x⟩ (B) at equilibration: -0.03127135395269869
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.018023912863683635
# Measured ⟨v_x⟩ (B): -0.006161347951360887
# Theory F_D/γ: 55.26315789473684
#
#
#
#
# F_D: 63.1578947368421
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.054888444334259615
# Measured ⟨v_x⟩ (B) at equilibration: -0.0002512575472873999
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.014687383458922112
# Measured ⟨v_x⟩ (B): -0.00731015336916915
# Theory F_D/γ: 63.1578947368421
#
#
#
#
# F_D: 71.05263157894737
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.00805116457101985
# Measured ⟨v_x⟩ (B) at equilibration: -0.022363386978985145
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.034961425643110285
# Measured ⟨v_x⟩ (B): -0.004034689166752564
# Theory F_D/γ: 71.05263157894737
#
#
#
#
# F_D: 78.94736842105263
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.04379813131203815
# Measured ⟨v_x⟩ (B) at equilibration: -0.012464421045744562
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.03623868585232337
# Measured ⟨v_x⟩ (B): -0.02039513166177024
# Theory F_D/γ: 78.94736842105263
#
#
#
#
# F_D: 86.84210526315789
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.061240434615875985
# Measured ⟨v_x⟩ (B) at equilibration: -0.09346867635545067
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.01064951479848431
# Measured ⟨v_x⟩ (B): -0.023072103260531152
# Theory F_D/γ: 86.84210526315789
#
#
#
#
# F_D: 94.73684210526315
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.06066052734051914
# Measured ⟨v_x⟩ (B) at equilibration: -0.017236111984261084
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.02233153333963183
# Measured ⟨v_x⟩ (B): 0.03226401854700103
# Theory F_D/γ: 94.73684210526315
#
#
#
#
# F_D: 102.63157894736841
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.06284279263590552
# Measured ⟨v_x⟩ (B) at equilibration: 0.014059961823658292
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.011932923353852078
# Measured ⟨v_x⟩ (B): 0.025752682807490483
# Theory F_D/γ: 102.63157894736841
#
#
#
#
# F_D: 110.52631578947368
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.05912660131341081
# Measured ⟨v_x⟩ (B) at equilibration: -0.032752998992775235
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.004464346681663407
# Measured ⟨v_x⟩ (B): 0.03700737500080452
# Theory F_D/γ: 110.52631578947368
#
#
#
#
# F_D: 118.42105263157895
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.06428034406734988
# Measured ⟨v_x⟩ (B) at equilibration: 0.06677475696175487
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.07714469644062807
# Measured ⟨v_x⟩ (B): 0.01115739277376983
# Theory F_D/γ: 118.42105263157895
#
#
#
#
# F_D: 126.3157894736842
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.04104640284756582
# Measured ⟨v_x⟩ (B) at equilibration: -0.16827413683551753
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.005
# Measured ⟨v_x⟩ (A): 0.026333187742490625
# Measured ⟨v_x⟩ (B): 0.016469981971698355
# Theory F_D/γ: 126.3157894736842
#
#
#
#
# F_D: 134.21052631578948
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.028451900006669674
# Measured ⟨v_x⟩ (B) at equilibration: 0.037907091681356496
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.016677141001905475
# Measured ⟨v_x⟩ (B): 0.015332247858331826
# Theory F_D/γ: 134.21052631578948
#
#
#
#
# F_D: 142.10526315789474
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.025754779617774618
# Measured ⟨v_x⟩ (B) at equilibration: 0.04409289832854638
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.026546092599726602
# Measured ⟨v_x⟩ (B): 0.04026988197787119
# Theory F_D/γ: 142.10526315789474
#
#
#
#
# F_D: 150.0
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.045956109570687353
# Measured ⟨v_x⟩ (B) at equilibration: -0.015376142511539778
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.0018967650580924
# Measured ⟨v_x⟩ (B): 0.013626810952617578
# Theory F_D/γ: 150.0
#
#
#
#
# F_D: 0.0
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.018197877775982044
# Measured ⟨v_x⟩ (B) at equilibration: -0.022179260762685987
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.012200430684272094
# Measured ⟨v_x⟩ (B): 0.03170996025732684
# Theory F_D/γ: 0.0
#
#
#
#
# F_D: 7.894736842105263
# Running Equilibration...
# Progress: 0%
# /var/folders/rm/s0k967k97p1dxnwxvw2t85vc0000gn/T/ipykernel_5814/991591013.py:136: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(6, 6))
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.026891059047103396
# Measured ⟨v_x⟩ (B) at equilibration: 0.021236985866437703
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.034048182421025655
# Measured ⟨v_x⟩ (B): 0.043412620992526886
# Theory F_D/γ: 7.894736842105263
#
#
#
#
# F_D: 15.789473684210526
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.05710568103117731
# Measured ⟨v_x⟩ (B) at equilibration: 0.010475780408409678
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.017781922334335874
# Measured ⟨v_x⟩ (B): -0.006873238450791956
# Theory F_D/γ: 15.789473684210526
#
#
#
#
# F_D: 23.684210526315788
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.012188228133438408
# Measured ⟨v_x⟩ (B) at equilibration: 0.06804912644985138
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.0377642072227176
# Measured ⟨v_x⟩ (B): -0.043564742211202614
# Theory F_D/γ: 23.684210526315788
#
#
#
#
# F_D: 31.57894736842105
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.08146384336559472
# Measured ⟨v_x⟩ (B) at equilibration: -0.017427104763601004
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.07888878775894127
# Measured ⟨v_x⟩ (B): 0.012595919754113673
# Theory F_D/γ: 31.57894736842105
#
#
#
#
# F_D: 39.473684210526315
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.05788657995404153
# Measured ⟨v_x⟩ (B) at equilibration: 0.11456941982969752
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.00427600433009146
# Measured ⟨v_x⟩ (B): -0.003724253508716051
# Theory F_D/γ: 39.473684210526315
#
#
#
#
# F_D: 47.368421052631575
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.015214303276959797
# Measured ⟨v_x⟩ (B) at equilibration: 0.01943424440825595
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.03002684427796988
# Measured ⟨v_x⟩ (B): 0.038884291416394254
# Theory F_D/γ: 47.368421052631575
#
#
#
#
# F_D: 55.26315789473684
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.030547615481444138
# Measured ⟨v_x⟩ (B) at equilibration: 0.029922633495465617
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.07238360896666676
# Measured ⟨v_x⟩ (B): 0.01061494819628526
# Theory F_D/γ: 55.26315789473684
#
#
#
#
# F_D: 63.1578947368421
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.0704731538382498
# Measured ⟨v_x⟩ (B) at equilibration: 0.033060752138867326
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.006346376403577617
# Measured ⟨v_x⟩ (B): -0.011202354696802603
# Theory F_D/γ: 63.1578947368421
#
#
#
#
# F_D: 71.05263157894737
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.024041874483269384
# Measured ⟨v_x⟩ (B) at equilibration: 0.0043123665238519295
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.01720191924647868
# Measured ⟨v_x⟩ (B): -0.033261905757624007
# Theory F_D/γ: 71.05263157894737
#
#
#
#
# F_D: 78.94736842105263
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.042815445575729166
# Measured ⟨v_x⟩ (B) at equilibration: -0.0010442936443476754
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.021778604341957507
# Measured ⟨v_x⟩ (B): -0.027355465030556986
# Theory F_D/γ: 78.94736842105263
#
#
#
#
# F_D: 86.84210526315789
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.02934262035867734
# Measured ⟨v_x⟩ (B) at equilibration: -0.015841207474461844
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.03385674203238244
# Measured ⟨v_x⟩ (B): -0.0017627456476933087
# Theory F_D/γ: 86.84210526315789
#
#
#
#
# F_D: 94.73684210526315
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.0104233527282139
# Measured ⟨v_x⟩ (B) at equilibration: -0.039480354058338246
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.013601047781345894
# Measured ⟨v_x⟩ (B): -0.019127210105115613
# Theory F_D/γ: 94.73684210526315
#
#
#
#
# F_D: 102.63157894736841
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.011358159670776769
# Measured ⟨v_x⟩ (B) at equilibration: -0.07855016512661164
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.021242602029624934
# Measured ⟨v_x⟩ (B): -0.011560220242947025
# Theory F_D/γ: 102.63157894736841
#
#
#
#
# F_D: 110.52631578947368
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.16274673662133166
# Measured ⟨v_x⟩ (B) at equilibration: -0.002491348826562323
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.007184790235787671
# Measured ⟨v_x⟩ (B): 0.0018572147737979956
# Theory F_D/γ: 110.52631578947368
#
#
#
#
# F_D: 118.42105263157895
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.010719554720447217
# Measured ⟨v_x⟩ (B) at equilibration: 0.05447286913921877
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.01778971096601497
# Measured ⟨v_x⟩ (B): -0.037941296867031876
# Theory F_D/γ: 118.42105263157895
#
#
#
#
# F_D: 126.3157894736842
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.03867439070285753
# Measured ⟨v_x⟩ (B) at equilibration: 0.01602666647678802
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.007777111818513377
# Measured ⟨v_x⟩ (B): 0.03130169597651672
# Theory F_D/γ: 126.3157894736842
#
#
#
#
# F_D: 134.21052631578948
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.00691559001348286
# Measured ⟨v_x⟩ (B) at equilibration: -0.032708399826252205
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.016866301696771575
# Measured ⟨v_x⟩ (B): 0.012040249166088696
# Theory F_D/γ: 134.21052631578948
#
#
#
#
# F_D: 142.10526315789474
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.05596795298084636
# Measured ⟨v_x⟩ (B) at equilibration: -0.022954517401650425
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.013242797986115605
# Measured ⟨v_x⟩ (B): -0.023056951505575584
# Theory F_D/γ: 142.10526315789474
#
#
#
#
# F_D: 150.0
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.016804785224254295
# Measured ⟨v_x⟩ (B) at equilibration: -0.025107142590637677
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.026669105618365555
# Measured ⟨v_x⟩ (B): -0.012107388822933114
# Theory F_D/γ: 150.0
#
#
#
#
# F_D: 0.0
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.001571689614681752
# Measured ⟨v_x⟩ (B) at equilibration: -0.008781171589832227
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.007340056269571821
# Measured ⟨v_x⟩ (B): 0.03785958696542313
# Theory F_D/γ: 0.0
#
#
#
#
# F_D: 7.894736842105263
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.01050443512778212
# Measured ⟨v_x⟩ (B) at equilibration: 0.015067056187580117
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.05467118417477423
# Measured ⟨v_x⟩ (B): -0.005087403568379451
# Theory F_D/γ: 7.894736842105263
#
#
#
#
# F_D: 15.789473684210526
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.028005905308346752
# Measured ⟨v_x⟩ (B) at equilibration: 0.03937308421288636
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.005
# Measured ⟨v_x⟩ (A): -0.010777023315712383
# Measured ⟨v_x⟩ (B): 0.028370927246745947
# Theory F_D/γ: 15.789473684210526
#
#
#
#
# F_D: 23.684210526315788
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.15666821890594126
# Measured ⟨v_x⟩ (B) at equilibration: 0.05178374636248516
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.03701550573292613
# Measured ⟨v_x⟩ (B): 0.05377036747806406
# Theory F_D/γ: 23.684210526315788
#
#
#
#
# F_D: 31.57894736842105
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.11151609597286291
# Measured ⟨v_x⟩ (B) at equilibration: 0.00999755224207403
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.06348611564197192
# Measured ⟨v_x⟩ (B): -0.008319469459624135
# Theory F_D/γ: 31.57894736842105
#
#
#
#
# F_D: 39.473684210526315
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.024830260284819376
# Measured ⟨v_x⟩ (B) at equilibration: 0.10511906478028367
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.02509646588516597
# Measured ⟨v_x⟩ (B): 0.030401437375854535
# Theory F_D/γ: 39.473684210526315
#
#
#
#
# F_D: 47.368421052631575
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.02250127498532742
# Measured ⟨v_x⟩ (B) at equilibration: -0.0071404194430687035
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.009660252950286118
# Measured ⟨v_x⟩ (B): -0.022558830770879484
# Theory F_D/γ: 47.368421052631575
#
#
#
#
# F_D: 55.26315789473684
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.028469727106135743
# Measured ⟨v_x⟩ (B) at equilibration: 0.08663841846353282
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.024443634561540258
# Measured ⟨v_x⟩ (B): 0.03996153580972986
# Theory F_D/γ: 55.26315789473684
#
#
#
#
# F_D: 63.1578947368421
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.01579436595657941
# Measured ⟨v_x⟩ (B) at equilibration: 0.03207658635409051
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.009724398154415193
# Measured ⟨v_x⟩ (B): -0.007036072681380907
# Theory F_D/γ: 63.1578947368421
#
#
#
#
# F_D: 71.05263157894737
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.051933742533578776
# Measured ⟨v_x⟩ (B) at equilibration: 0.018835603601714872
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): 0.042839784661943554
# Measured ⟨v_x⟩ (B): 0.035038162483494
# Theory F_D/γ: 71.05263157894737
#
#
#
#
# F_D: 78.94736842105263
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.025878582349015473
# Measured ⟨v_x⟩ (B) at equilibration: -0.011156878825418612
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.0
# Measured ⟨v_x⟩ (A): -0.006140720560493721
# Measured ⟨v_x⟩ (B): 0.04030104104939664
# Theory F_D/γ: 78.94736842105263
#
#
#
#
# F_D: 86.84210526315789
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: -0.0179833037421359
# Measured ⟨v_x⟩ (B) at equilibration: 0.04756118859775546
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Simulation finished.
# Phi: 0.02
# Measured ⟨v_x⟩ (A): 0.04922141567263135
# Measured ⟨v_x⟩ (B): 0.022886663234742165
# Theory F_D/γ: 86.84210526315789
#
#
#
#
# F_D: 94.73684210526315
# Running Equilibration...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
# Progress: 80%
# Progress: 90%
# Progress: 100%
# Measured ⟨v_x⟩ (A) at equilibration: 0.09718857337908764
# Measured ⟨v_x⟩ (B) at equilibration: 0.013981446241399567
# Running Brownian Dynamics simulation...
# Progress: 0%
# Progress: 10%
# Progress: 20%
# Progress: 30%
# Progress: 40%
# Progress: 50%
# Progress: 60%
# Progress: 70%
